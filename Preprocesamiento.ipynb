# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Preprocesamiento

# %%
df = pd.read_csv('dataframes/df_eda.csv')

# %% [markdown]
# ## 2.1 Segmentación en ventanas de tiempo

# %%
def segment_by_window(group, window_size):
    """
    Segments data into windows of specified size.

    Args:
        group (pd.DataFrame): Subject's data.
        window_size (int): Size of each time window.

    Returns:
        list: List of DataFrames, each representing a window of data.
    """
    windows = []
    for start in range(0, len(group), window_size):
        end = start + window_size
        if end <= len(group):
            window = group.iloc[start:end].copy()
            windows.append(window)
    return windows

def add_window_metadata(windows, subject_id):
    """
    Adds metadata like window number, window ID, and majority label.

    Args:
        windows (list): List of window DataFrames.
        subject_id (int): Subject identifier.

    Returns:
        list: List of windows with added metadata.
    """
    for i, window in enumerate(windows):
        window['subject_id'] = subject_id
        window['window_number'] = i
        window['window_id'] = f"{subject_id}_{window['window_number'].iloc[0]}"

        majority_label = get_majority_label(window)
        window['labels_in_window'] = [majority_label] * len(window)
    return windows

def get_majority_label(window):
    """
    Gets the majority label for a window.

    Args:
        window (pd.DataFrame): Window data.

    Returns:
        str: Majority label, or None if no majority.
    """
    label_counts = window['activityID'].value_counts()
    majority_label = label_counts.idxmax() if label_counts.max() / len(window) > 0.5 else window['label'].iloc[0]
    return majority_label

def process_subject_data(mhealth_df, window_size):
    """
    Processes all subject data by segmenting and adding metadata.

    Args:
        mhealth_df (pd.DataFrame): Data of multiple subjects.
        window_size (int): Size of each time window.

    Returns:
        list: List of windows with metadata.
    """
    all_windows = []
    for subject_id, group in mhealth_df.groupby('subject_id'):
        group = group.reset_index(drop=True)

        windows = segment_by_window(group, window_size)
        windows = add_window_metadata(windows, subject_id)
        all_windows.extend(windows)
    
    return all_windows

def concatenate_windows(windows):
    """
    Concatenates all windows into a single DataFrame.

    Args:
        windows (list): List of window DataFrames.

    Returns:
        pd.DataFrame: Concatenated DataFrame of all windows.
    """
    return pd.concat(windows).reset_index(drop=True)

def display_basic_info(ventanas_df, windows):
    """
    Displays basic info about windows and their majority labels.

    Args:
        ventanas_df (pd.DataFrame): DataFrame of windows with metadata.
        windows (list): List of processed windows.
    """
    print(f"Ventanas generadas: {len(windows)}")
    print(f"Tamaño del DataFrame de ventanas: {ventanas_df.shape}")

    for window_id, group in ventanas_df.groupby('window_id'):
        majority_label = group['labels_in_window'].iloc[0]
        print(f"Window ID: {window_id} - Majority Label: {majority_label}")

# Parameters
window_size = 150  # 3 seconds * 50 Hz

print(df.shape)
windows = process_subject_data(df, window_size)

# Concatenate all windows into a single DataFrame
pamap_windowed = concatenate_windows(windows)

display_basic_info(pamap_windowed, windows)
# Out:
# (1942872, 55)
# Ventanas generadas: 12948
# Tamaño del DataFrame de ventanas: (1942200, 58)
# Window ID: subject101_0 - Majority Label: 1
# Window ID: subject101_1 - Majority Label: 1
# Window ID: subject101_10 - Majority Label: 1
# Window ID: subject101_100 - Majority Label: 1
# Window ID: subject101_1000 - Majority Label: 4
# Window ID: subject101_1001 - Majority Label: 4
# Window ID: subject101_1002 - Majority Label: 4
# Window ID: subject101_1003 - Majority Label: 4
# Window ID: subject101_1004 - Majority Label: 4
# Window ID: subject101_1005 - Majority Label: 4
# Window ID: subject101_1006 - Majority Label: 4
# Window ID: subject101_1007 - Majority Label: 4
# Window ID: subject101_1008 - Majority Label: 4
# Window ID: subject101_1009 - Majority Label: 4
# Window ID: subject101_101 - Majority Label: 1
# Window ID: subject101_1010 - Majority Label: 4
# Window ID: subject101_1011 - Majority Label: 4
# Window ID: subject101_1012 - Majority Label: 4
# Window ID: subject101_1013 - Majority Label: 4
# Window ID: subject101_1014 - Majority Label: 4
# Window ID: subject101_1015 - Majority Label: 4
# Window ID: subject101_1016 - Majority Label: 4
# Window ID: subject101_1017 - Majority Label: 4
# Window ID: subject101_1018 - Majority Label: 4
# Window ID: subject101_1019 - Majority Label: 4
# Window ID: subject101_102 - Majority Label: 1
# Window ID: subject101_1020 - Majority Label: 4
# Window ID: subject101_1021 - Majority Label: 4
# Window ID: subject101_1022 - Majority Label: 4
# Window ID: subject101_1023 - Majority Label: 4
# Window ID: subject101_1024 - Majority Label: 4
# Window ID: subject101_1025 - Majority Label: 4
# Window ID: subject101_1026 - Majority Label: 4
# Window ID: subject101_1027 - Majority Label: 4
# Window ID: subject101_1028 - Majority Label: 4
# Window ID: subject101_1029 - Majority Label: 4
# Window ID: subject101_103 - Majority Label: 1
# Window ID: subject101_1030 - Majority Label: 4
# Window ID: subject101_1031 - Majority Label: 4
# Window ID: subject101_1032 - Majority Label: 4
# Window ID: subject101_1033 - Majority Label: 4
# Window ID: subject101_1034 - Majority Label: 4
# Window ID: subject101_1035 - Majority Label: 4
# Window ID: subject101_1036 - Majority Label: 4
# Window ID: subject101_1037 - Majority Label: 4
# Window ID: subject101_1038 - Majority Label: 4
# Window ID: subject101_1039 - Majority Label: 4
# Window ID: subject101_104 - Majority Label: 1
# Window ID: subject101_1040 - Majority Label: 4
# Window ID: subject101_1041 - Majority Label: 4
# Window ID: subject101_1042 - Majority Label: 4
# Window ID: subject101_1043 - Majority Label: 4
# Window ID: subject101_1044 - Majority Label: 4
# Window ID: subject101_1045 - Majority Label: 4
# Window ID: subject101_1046 - Majority Label: 4
# Window ID: subject101_1047 - Majority Label: 4
# Window ID: subject101_1048 - Majority Label: 4
# Window ID: subject101_1049 - Majority Label: 4
# Window ID: subject101_105 - Majority Label: 1
# Window ID: subject101_1050 - Majority Label: 4
# Window ID: subject101_1051 - Majority Label: 4
# Window ID: subject101_1052 - Majority Label: 4
# Window ID: subject101_1053 - Majority Label: 4
# Window ID: subject101_1054 - Majority Label: 4
# Window ID: subject101_1055 - Majority Label: 4
# Window ID: subject101_1056 - Majority Label: 4
# Window ID: subject101_1057 - Majority Label: 4
# Window ID: subject101_1058 - Majority Label: 4
# Window ID: subject101_1059 - Majority Label: 4
# Window ID: subject101_106 - Majority Label: 1
# Window ID: subject101_1060 - Majority Label: 4
# Window ID: subject101_1061 - Majority Label: 4
# Window ID: subject101_1062 - Majority Label: 4
# Window ID: subject101_1063 - Majority Label: 4
# Window ID: subject101_1064 - Majority Label: 4
# Window ID: subject101_1065 - Majority Label: 4
# Window ID: subject101_1066 - Majority Label: 4
# Window ID: subject101_1067 - Majority Label: 4
# Window ID: subject101_1068 - Majority Label: 4
# Window ID: subject101_1069 - Majority Label: 4
# Window ID: subject101_107 - Majority Label: 1
# Window ID: subject101_1070 - Majority Label: 4
# Window ID: subject101_1071 - Majority Label: 4
# Window ID: subject101_1072 - Majority Label: 4
# Window ID: subject101_1073 - Majority Label: 4
# Window ID: subject101_1074 - Majority Label: 4
# Window ID: subject101_1075 - Majority Label: 4
# Window ID: subject101_1076 - Majority Label: 4
# Window ID: subject101_1077 - Majority Label: 4
# Window ID: subject101_1078 - Majority Label: 4
# Window ID: subject101_1079 - Majority Label: 4
# Window ID: subject101_108 - Majority Label: 1
# Window ID: subject101_1080 - Majority Label: 4
# Window ID: subject101_1081 - Majority Label: 4
# Window ID: subject101_1082 - Majority Label: 4
# Window ID: subject101_1083 - Majority Label: 4
# Window ID: subject101_1084 - Majority Label: 4
# Window ID: subject101_1085 - Majority Label: 4
# Window ID: subject101_1086 - Majority Label: 4
# Window ID: subject101_1087 - Majority Label: 4
# Window ID: subject101_1088 - Majority Label: 4
# Window ID: subject101_1089 - Majority Label: 4
# Window ID: subject101_109 - Majority Label: 1
# Window ID: subject101_1090 - Majority Label: 4
# Window ID: subject101_1091 - Majority Label: 4
# Window ID: subject101_1092 - Majority Label: 4
# Window ID: subject101_1093 - Majority Label: 4
# Window ID: subject101_1094 - Majority Label: 4
# Window ID: subject101_1095 - Majority Label: 4
# Window ID: subject101_1096 - Majority Label: 4
# Window ID: subject101_1097 - Majority Label: 4
# Window ID: subject101_1098 - Majority Label: 4
# Window ID: subject101_1099 - Majority Label: 4
# Window ID: subject101_11 - Majority Label: 1
# Window ID: subject101_110 - Majority Label: 1
# Window ID: subject101_1100 - Majority Label: 4
# Window ID: subject101_1101 - Majority Label: 4
# Window ID: subject101_1102 - Majority Label: 4
# Window ID: subject101_1103 - Majority Label: 4
# Window ID: subject101_1104 - Majority Label: 4
# Window ID: subject101_1105 - Majority Label: 4
# Window ID: subject101_1106 - Majority Label: 4
# Window ID: subject101_1107 - Majority Label: 4
# Window ID: subject101_1108 - Majority Label: 4
# Window ID: subject101_1109 - Majority Label: 4
# Window ID: subject101_111 - Majority Label: 1
# Window ID: subject101_1110 - Majority Label: 4
# Window ID: subject101_1111 - Majority Label: 4
# Window ID: subject101_1112 - Majority Label: 4
# Window ID: subject101_1113 - Majority Label: 4
# Window ID: subject101_1114 - Majority Label: 4
# Window ID: subject101_1115 - Majority Label: 4
# Window ID: subject101_1116 - Majority Label: 4
# Window ID: subject101_1117 - Majority Label: 4
# Window ID: subject101_1118 - Majority Label: 4
# Window ID: subject101_1119 - Majority Label: 4
# Window ID: subject101_112 - Majority Label: 1
# Window ID: subject101_1120 - Majority Label: 4
# Window ID: subject101_1121 - Majority Label: 4
# Window ID: subject101_1122 - Majority Label: 4
# Window ID: subject101_1123 - Majority Label: 4
# Window ID: subject101_1124 - Majority Label: 4
# Window ID: subject101_1125 - Majority Label: 4
# Window ID: subject101_1126 - Majority Label: 4
# Window ID: subject101_1127 - Majority Label: 4
# Window ID: subject101_1128 - Majority Label: 4
# Window ID: subject101_1129 - Majority Label: 4
# Window ID: subject101_113 - Majority Label: 1
# Window ID: subject101_1130 - Majority Label: 4
# Window ID: subject101_1131 - Majority Label: 4
# Window ID: subject101_1132 - Majority Label: 4
# Window ID: subject101_1133 - Majority Label: 4
# Window ID: subject101_1134 - Majority Label: 4
# Window ID: subject101_1135 - Majority Label: 4
# Window ID: subject101_1136 - Majority Label: 4
# Window ID: subject101_1137 - Majority Label: 4
# Window ID: subject101_1138 - Majority Label: 4
# Window ID: subject101_1139 - Majority Label: 4
# Window ID: subject101_114 - Majority Label: 1
# Window ID: subject101_1140 - Majority Label: 4
# Window ID: subject101_1141 - Majority Label: 4
# Window ID: subject101_1142 - Majority Label: 4
# Window ID: subject101_1143 - Majority Label: 4
# Window ID: subject101_1144 - Majority Label: 4
# Window ID: subject101_1145 - Majority Label: 4
# Window ID: subject101_1146 - Majority Label: 7
# Window ID: subject101_1147 - Majority Label: 7
# Window ID: subject101_1148 - Majority Label: 7
# Window ID: subject101_1149 - Majority Label: 7
# Window ID: subject101_115 - Majority Label: 1
# Window ID: subject101_1150 - Majority Label: 7
# Window ID: subject101_1151 - Majority Label: 7
# Window ID: subject101_1152 - Majority Label: 7
# Window ID: subject101_1153 - Majority Label: 7
# Window ID: subject101_1154 - Majority Label: 7
# Window ID: subject101_1155 - Majority Label: 7
# Window ID: subject101_1156 - Majority Label: 7
# Window ID: subject101_1157 - Majority Label: 7
# Window ID: subject101_1158 - Majority Label: 7
# Window ID: subject101_1159 - Majority Label: 7
# Window ID: subject101_116 - Majority Label: 1
# Window ID: subject101_1160 - Majority Label: 7
# Window ID: subject101_1161 - Majority Label: 7
# Window ID: subject101_1162 - Majority Label: 7
# Window ID: subject101_1163 - Majority Label: 7
# Window ID: subject101_1164 - Majority Label: 7
# Window ID: subject101_1165 - Majority Label: 7
# Window ID: subject101_1166 - Majority Label: 7
# Window ID: subject101_1167 - Majority Label: 7
# Window ID: subject101_1168 - Majority Label: 7
# Window ID: subject101_1169 - Majority Label: 7
# Window ID: subject101_117 - Majority Label: 1
# Window ID: subject101_1170 - Majority Label: 7
# Window ID: subject101_1171 - Majority Label: 7
# Window ID: subject101_1172 - Majority Label: 7
# Window ID: subject101_1173 - Majority Label: 7
# Window ID: subject101_1174 - Majority Label: 7
# Window ID: subject101_1175 - Majority Label: 7
# Window ID: subject101_1176 - Majority Label: 7
# Window ID: subject101_1177 - Majority Label: 7
# Window ID: subject101_1178 - Majority Label: 7
# Window ID: subject101_1179 - Majority Label: 7
# Window ID: subject101_118 - Majority Label: 1
# Window ID: subject101_1180 - Majority Label: 7
# Window ID: subject101_1181 - Majority Label: 7
# Window ID: subject101_1182 - Majority Label: 7
# Window ID: subject101_1183 - Majority Label: 7
# Window ID: subject101_1184 - Majority Label: 7
# Window ID: subject101_1185 - Majority Label: 7
# Window ID: subject101_1186 - Majority Label: 7
# Window ID: subject101_1187 - Majority Label: 7
# Window ID: subject101_1188 - Majority Label: 7
# Window ID: subject101_1189 - Majority Label: 7
# Window ID: subject101_119 - Majority Label: 1
# Window ID: subject101_1190 - Majority Label: 7
# Window ID: subject101_1191 - Majority Label: 7
# Window ID: subject101_1192 - Majority Label: 7
# Window ID: subject101_1193 - Majority Label: 7
# Window ID: subject101_1194 - Majority Label: 7
# Window ID: subject101_1195 - Majority Label: 7
# Window ID: subject101_1196 - Majority Label: 7
# Window ID: subject101_1197 - Majority Label: 7
# Window ID: subject101_1198 - Majority Label: 7
# Window ID: subject101_1199 - Majority Label: 7
# Window ID: subject101_12 - Majority Label: 1
# Window ID: subject101_120 - Majority Label: 1
# Window ID: subject101_1200 - Majority Label: 7
# Window ID: subject101_1201 - Majority Label: 7
# Window ID: subject101_1202 - Majority Label: 7
# Window ID: subject101_1203 - Majority Label: 7
# Window ID: subject101_1204 - Majority Label: 7
# Window ID: subject101_1205 - Majority Label: 7
# Window ID: subject101_1206 - Majority Label: 7
# Window ID: subject101_1207 - Majority Label: 7
# Window ID: subject101_1208 - Majority Label: 7
# Window ID: subject101_1209 - Majority Label: 7
# Window ID: subject101_121 - Majority Label: 1
# Window ID: subject101_1210 - Majority Label: 7
# Window ID: subject101_1211 - Majority Label: 7
# Window ID: subject101_1212 - Majority Label: 7
# Window ID: subject101_1213 - Majority Label: 7
# Window ID: subject101_1214 - Majority Label: 7
# Window ID: subject101_1215 - Majority Label: 7
# Window ID: subject101_1216 - Majority Label: 7
# Window ID: subject101_1217 - Majority Label: 7
# Window ID: subject101_1218 - Majority Label: 7
# Window ID: subject101_1219 - Majority Label: 7
# Window ID: subject101_122 - Majority Label: 1
# Window ID: subject101_1220 - Majority Label: 7
# Window ID: subject101_1221 - Majority Label: 7
# Window ID: subject101_1222 - Majority Label: 7
# Window ID: subject101_1223 - Majority Label: 7
# Window ID: subject101_1224 - Majority Label: 7
# Window ID: subject101_1225 - Majority Label: 7
# Window ID: subject101_1226 - Majority Label: 7
# Window ID: subject101_1227 - Majority Label: 7
# Window ID: subject101_1228 - Majority Label: 7
# Window ID: subject101_1229 - Majority Label: 7
# Window ID: subject101_123 - Majority Label: 1
# Window ID: subject101_1230 - Majority Label: 7
# Window ID: subject101_1231 - Majority Label: 7
# Window ID: subject101_1232 - Majority Label: 7
# Window ID: subject101_1233 - Majority Label: 7
# Window ID: subject101_1234 - Majority Label: 7
# Window ID: subject101_1235 - Majority Label: 7
# Window ID: subject101_1236 - Majority Label: 7
# Window ID: subject101_1237 - Majority Label: 7
# Window ID: subject101_1238 - Majority Label: 7
# Window ID: subject101_1239 - Majority Label: 7
# Window ID: subject101_124 - Majority Label: 1
# Window ID: subject101_1240 - Majority Label: 7
# Window ID: subject101_1241 - Majority Label: 7
# Window ID: subject101_1242 - Majority Label: 7
# Window ID: subject101_1243 - Majority Label: 7
# Window ID: subject101_1244 - Majority Label: 7
# Window ID: subject101_1245 - Majority Label: 7
# Window ID: subject101_1246 - Majority Label: 7
# Window ID: subject101_1247 - Majority Label: 7
# Window ID: subject101_1248 - Majority Label: 7
# Window ID: subject101_1249 - Majority Label: 7
# Window ID: subject101_125 - Majority Label: 1
# Window ID: subject101_1250 - Majority Label: 7
# Window ID: subject101_1251 - Majority Label: 7
# Window ID: subject101_1252 - Majority Label: 7
# Window ID: subject101_1253 - Majority Label: 7
# Window ID: subject101_1254 - Majority Label: 7
# Window ID: subject101_1255 - Majority Label: 7
# Window ID: subject101_1256 - Majority Label: 7
# Window ID: subject101_1257 - Majority Label: 7
# Window ID: subject101_1258 - Majority Label: 7
# Window ID: subject101_1259 - Majority Label: 7
# Window ID: subject101_126 - Majority Label: 1
# Window ID: subject101_1260 - Majority Label: 7
# Window ID: subject101_1261 - Majority Label: 7
# Window ID: subject101_1262 - Majority Label: 7
# Window ID: subject101_1263 - Majority Label: 7
# Window ID: subject101_1264 - Majority Label: 7
# Window ID: subject101_1265 - Majority Label: 7
# Window ID: subject101_1266 - Majority Label: 7
# Window ID: subject101_1267 - Majority Label: 7
# Window ID: subject101_1268 - Majority Label: 7
# Window ID: subject101_1269 - Majority Label: 7
# Window ID: subject101_127 - Majority Label: 1
# Window ID: subject101_1270 - Majority Label: 7
# Window ID: subject101_1271 - Majority Label: 7
# Window ID: subject101_1272 - Majority Label: 7
# Window ID: subject101_1273 - Majority Label: 7
# Window ID: subject101_1274 - Majority Label: 7
# Window ID: subject101_1275 - Majority Label: 7
# Window ID: subject101_1276 - Majority Label: 7
# Window ID: subject101_1277 - Majority Label: 7
# Window ID: subject101_1278 - Majority Label: 7
# Window ID: subject101_1279 - Majority Label: 7
# Window ID: subject101_128 - Majority Label: 1
# Window ID: subject101_1280 - Majority Label: 7
# Window ID: subject101_1281 - Majority Label: 6
# Window ID: subject101_1282 - Majority Label: 6
# Window ID: subject101_1283 - Majority Label: 6
# Window ID: subject101_1284 - Majority Label: 6
# Window ID: subject101_1285 - Majority Label: 6
# Window ID: subject101_1286 - Majority Label: 6
# Window ID: subject101_1287 - Majority Label: 6
# Window ID: subject101_1288 - Majority Label: 6
# Window ID: subject101_1289 - Majority Label: 6
# Window ID: subject101_129 - Majority Label: 1
# Window ID: subject101_1290 - Majority Label: 6
# Window ID: subject101_1291 - Majority Label: 6
# Window ID: subject101_1292 - Majority Label: 6
# Window ID: subject101_1293 - Majority Label: 6
# Window ID: subject101_1294 - Majority Label: 6
# Window ID: subject101_1295 - Majority Label: 6
# Window ID: subject101_1296 - Majority Label: 6
# Window ID: subject101_1297 - Majority Label: 6
# Window ID: subject101_1298 - Majority Label: 6
# Window ID: subject101_1299 - Majority Label: 6
# Window ID: subject101_13 - Majority Label: 1
# Window ID: subject101_130 - Majority Label: 1
# Window ID: subject101_1300 - Majority Label: 6
# Window ID: subject101_1301 - Majority Label: 6
# Window ID: subject101_1302 - Majority Label: 6
# Window ID: subject101_1303 - Majority Label: 6
# Window ID: subject101_1304 - Majority Label: 6
# Window ID: subject101_1305 - Majority Label: 6
# Window ID: subject101_1306 - Majority Label: 6
# Window ID: subject101_1307 - Majority Label: 6
# Window ID: subject101_1308 - Majority Label: 6
# Window ID: subject101_1309 - Majority Label: 6
# Window ID: subject101_131 - Majority Label: 1
# Window ID: subject101_1310 - Majority Label: 6
# Window ID: subject101_1311 - Majority Label: 6
# Window ID: subject101_1312 - Majority Label: 6
# Window ID: subject101_1313 - Majority Label: 6
# Window ID: subject101_1314 - Majority Label: 6
# Window ID: subject101_1315 - Majority Label: 6
# Window ID: subject101_1316 - Majority Label: 6
# Window ID: subject101_1317 - Majority Label: 6
# Window ID: subject101_1318 - Majority Label: 6
# Window ID: subject101_1319 - Majority Label: 6
# Window ID: subject101_132 - Majority Label: 1
# Window ID: subject101_1320 - Majority Label: 6
# Window ID: subject101_1321 - Majority Label: 6
# Window ID: subject101_1322 - Majority Label: 6
# Window ID: subject101_1323 - Majority Label: 6
# Window ID: subject101_1324 - Majority Label: 6
# Window ID: subject101_1325 - Majority Label: 6
# Window ID: subject101_1326 - Majority Label: 6
# Window ID: subject101_1327 - Majority Label: 6
# Window ID: subject101_1328 - Majority Label: 6
# Window ID: subject101_1329 - Majority Label: 6
# Window ID: subject101_133 - Majority Label: 1
# Window ID: subject101_1330 - Majority Label: 6
# Window ID: subject101_1331 - Majority Label: 6
# Window ID: subject101_1332 - Majority Label: 6
# Window ID: subject101_1333 - Majority Label: 6
# Window ID: subject101_1334 - Majority Label: 6
# Window ID: subject101_1335 - Majority Label: 6
# Window ID: subject101_1336 - Majority Label: 6
# Window ID: subject101_1337 - Majority Label: 6
# Window ID: subject101_1338 - Majority Label: 6
# Window ID: subject101_1339 - Majority Label: 6
# Window ID: subject101_134 - Majority Label: 1
# Window ID: subject101_1340 - Majority Label: 6
# Window ID: subject101_1341 - Majority Label: 6
# Window ID: subject101_1342 - Majority Label: 6
# Window ID: subject101_1343 - Majority Label: 6
# Window ID: subject101_1344 - Majority Label: 6
# Window ID: subject101_1345 - Majority Label: 6
# Window ID: subject101_1346 - Majority Label: 6
# Window ID: subject101_1347 - Majority Label: 6
# Window ID: subject101_1348 - Majority Label: 6
# Window ID: subject101_1349 - Majority Label: 6
# Window ID: subject101_135 - Majority Label: 1
# Window ID: subject101_1350 - Majority Label: 6
# Window ID: subject101_1351 - Majority Label: 6
# Window ID: subject101_1352 - Majority Label: 6
# Window ID: subject101_1353 - Majority Label: 6
# Window ID: subject101_1354 - Majority Label: 6
# Window ID: subject101_1355 - Majority Label: 6
# Window ID: subject101_1356 - Majority Label: 6
# Window ID: subject101_1357 - Majority Label: 6
# Window ID: subject101_1358 - Majority Label: 6
# Window ID: subject101_1359 - Majority Label: 6
# Window ID: subject101_136 - Majority Label: 1
# Window ID: subject101_1360 - Majority Label: 6
# Window ID: subject101_1361 - Majority Label: 6
# Window ID: subject101_1362 - Majority Label: 6
# Window ID: subject101_1363 - Majority Label: 6
# Window ID: subject101_1364 - Majority Label: 6
# Window ID: subject101_1365 - Majority Label: 6
# Window ID: subject101_1366 - Majority Label: 6
# Window ID: subject101_1367 - Majority Label: 6
# Window ID: subject101_1368 - Majority Label: 6
# Window ID: subject101_1369 - Majority Label: 6
# Window ID: subject101_137 - Majority Label: 1
# Window ID: subject101_1370 - Majority Label: 6
# Window ID: subject101_1432 - Majority Label: 6
# Window ID: subject101_1433 - Majority Label: 6
# Window ID: subject101_1434 - Majority Label: 6
# Window ID: subject101_1435 - Majority Label: 6
# Window ID: subject101_1436 - Majority Label: 6
# Window ID: subject101_1437 - Majority Label: 6
# Window ID: subject101_1438 - Majority Label: 6
# Window ID: subject101_1439 - Majority Label: 5
# Window ID: subject101_144 - Majority Label: 1
# Window ID: subject101_1440 - Majority Label: 5
# Window ID: subject101_1441 - Majority Label: 5
# Window ID: subject101_1442 - Majority Label: 5
# Window ID: subject101_1443 - Majority Label: 5
# Window ID: subject101_1444 - Majority Label: 5
# Window ID: subject101_1445 - Majority Label: 5
# Window ID: subject101_1446 - Majority Label: 5
# Window ID: subject101_1447 - Majority Label: 5
# Window ID: subject101_1448 - Majority Label: 5
# Window ID: subject101_1449 - Majority Label: 5
# Window ID: subject101_145 - Majority Label: 1
# Window ID: subject101_1450 - Majority Label: 5
# Window ID: subject101_1451 - Majority Label: 5
# Window ID: subject101_1452 - Majority Label: 5
# Window ID: subject101_1453 - Majority Label: 5
# Window ID: subject101_1454 - Majority Label: 5
# Window ID: subject101_1455 - Majority Label: 5
# Window ID: subject101_1456 - Majority Label: 5
# Window ID: subject101_1457 - Majority Label: 5
# Window ID: subject101_1458 - Majority Label: 5
# Window ID: subject101_1459 - Majority Label: 5
# Window ID: subject101_146 - Majority Label: 1
# Window ID: subject101_1460 - Majority Label: 5
# Window ID: subject101_1461 - Majority Label: 5
# Window ID: subject101_1462 - Majority Label: 5
# Window ID: subject101_1463 - Majority Label: 5
# Window ID: subject101_1464 - Majority Label: 5
# Window ID: subject101_1465 - Majority Label: 5
# Window ID: subject101_1466 - Majority Label: 5
# Window ID: subject101_1467 - Majority Label: 5
# Window ID: subject101_1468 - Majority Label: 5
# Window ID: subject101_1469 - Majority Label: 5
# Window ID: subject101_147 - Majority Label: 1
# Window ID: subject101_1470 - Majority Label: 5
# Window ID: subject101_1471 - Majority Label: 5
# Window ID: subject101_1472 - Majority Label: 5
# Window ID: subject101_1473 - Majority Label: 5
# Window ID: subject101_1474 - Majority Label: 5
# Window ID: subject101_1475 - Majority Label: 5
# Window ID: subject101_1476 - Majority Label: 5
# Window ID: subject101_1477 - Majority Label: 5
# Window ID: subject101_1478 - Majority Label: 5
# Window ID: subject101_1479 - Majority Label: 5
# Window ID: subject101_148 - Majority Label: 1
# Window ID: subject101_1480 - Majority Label: 5
# Window ID: subject101_1481 - Majority Label: 5
# Window ID: subject101_1482 - Majority Label: 5
# Window ID: subject101_1483 - Majority Label: 5
# Window ID: subject101_1484 - Majority Label: 5
# Window ID: subject101_1485 - Majority Label: 5
# Window ID: subject101_1486 - Majority Label: 5
# Window ID: subject101_1487 - Majority Label: 5
# Window ID: subject101_1488 - Majority Label: 5
# Window ID: subject101_1489 - Majority Label: 5
# Window ID: subject101_149 - Majority Label: 1
# Window ID: subject101_1490 - Majority Label: 5
# Window ID: subject101_1491 - Majority Label: 5
# Window ID: subject101_1492 - Majority Label: 5
# Window ID: subject101_1493 - Majority Label: 5
# Window ID: subject101_1494 - Majority Label: 5
# Window ID: subject101_1495 - Majority Label: 5
# Window ID: subject101_1496 - Majority Label: 5
# Window ID: subject101_1497 - Majority Label: 5
# Window ID: subject101_1498 - Majority Label: 5
# Window ID: subject101_1499 - Majority Label: 5
# Window ID: subject101_15 - Majority Label: 1
# Window ID: subject101_150 - Majority Label: 1
# Window ID: subject101_1500 - Majority Label: 5
# Window ID: subject101_1501 - Majority Label: 5
# Window ID: subject101_1502 - Majority Label: 5
# Window ID: subject101_1503 - Majority Label: 5
# Window ID: subject101_1504 - Majority Label: 5
# Window ID: subject101_1505 - Majority Label: 5
# Window ID: subject101_1506 - Majority Label: 5
# Window ID: subject101_1507 - Majority Label: 5
# Window ID: subject101_1508 - Majority Label: 5
# Window ID: subject101_1509 - Majority Label: 5
# Window ID: subject101_151 - Majority Label: 1
# Window ID: subject101_1510 - Majority Label: 5
# Window ID: subject101_1511 - Majority Label: 5
# Window ID: subject101_1512 - Majority Label: 5
# Window ID: subject101_1513 - Majority Label: 5
# Window ID: subject101_1514 - Majority Label: 5
# Window ID: subject101_1515 - Majority Label: 5
# Window ID: subject101_1516 - Majority Label: 5
# Window ID: subject101_1517 - Majority Label: 5
# Window ID: subject101_1518 - Majority Label: 5
# Window ID: subject101_1519 - Majority Label: 5
# Window ID: subject101_152 - Majority Label: 1
# Window ID: subject101_1520 - Majority Label: 5
# Window ID: subject101_1521 - Majority Label: 5
# Window ID: subject101_1522 - Majority Label: 5
# Window ID: subject101_1523 - Majority Label: 5
# Window ID: subject101_1524 - Majority Label: 5
# Window ID: subject101_1525 - Majority Label: 5
# Window ID: subject101_1526 - Majority Label: 5
# Window ID: subject101_1527 - Majority Label: 5
# Window ID: subject101_1528 - Majority Label: 5
# Window ID: subject101_1529 - Majority Label: 5
# Window ID: subject101_153 - Majority Label: 1
# Window ID: subject101_1530 - Majority Label: 5
# Window ID: subject101_1531 - Majority Label: 5
# Window ID: subject101_1532 - Majority Label: 5
# Window ID: subject101_1533 - Majority Label: 5
# Window ID: subject101_1534 - Majority Label: 5
# Window ID: subject101_1535 - Majority Label: 5
# Window ID: subject101_1536 - Majority Label: 5
# Window ID: subject101_1537 - Majority Label: 5
# Window ID: subject101_1538 - Majority Label: 5
# Window ID: subject101_1539 - Majority Label: 5
# Window ID: subject101_154 - Majority Label: 1
# Window ID: subject101_1540 - Majority Label: 5
# Window ID: subject101_1541 - Majority Label: 5
# Window ID: subject101_1542 - Majority Label: 5
# Window ID: subject101_1543 - Majority Label: 5
# Window ID: subject101_1544 - Majority Label: 5
# Window ID: subject101_1545 - Majority Label: 5
# Window ID: subject101_1546 - Majority Label: 5
# Window ID: subject101_1547 - Majority Label: 5
# Window ID: subject101_1548 - Majority Label: 5
# Window ID: subject101_1549 - Majority Label: 5
# Window ID: subject101_155 - Majority Label: 1
# Window ID: subject101_1550 - Majority Label: 5
# Window ID: subject101_1551 - Majority Label: 5
# Window ID: subject101_1552 - Majority Label: 5
# Window ID: subject101_1553 - Majority Label: 5
# Window ID: subject101_1554 - Majority Label: 5
# Window ID: subject101_1555 - Majority Label: 5
# Window ID: subject101_1556 - Majority Label: 5
# Window ID: subject101_1557 - Majority Label: 5
# Window ID: subject101_1558 - Majority Label: 5
# Window ID: subject101_1559 - Majority Label: 5
# Window ID: subject101_156 - Majority Label: 1
# Window ID: subject101_1560 - Majority Label: 5
# Window ID: subject101_1561 - Majority Label: 5
# Window ID: subject101_1562 - Majority Label: 5
# Window ID: subject101_1563 - Majority Label: 5
# Window ID: subject101_1564 - Majority Label: 5
# Window ID: subject101_1565 - Majority Label: 5
# Window ID: subject101_1566 - Majority Label: 5
# Window ID: subject101_1567 - Majority Label: 5
# Window ID: subject101_1568 - Majority Label: 5
# Window ID: subject101_1569 - Majority Label: 5
# Window ID: subject101_157 - Majority Label: 1
# Window ID: subject101_1570 - Majority Label: 5
# Window ID: subject101_1571 - Majority Label: 5
# Window ID: subject101_1572 - Majority Label: 5
# Window ID: subject101_1573 - Majority Label: 5
# Window ID: subject101_1574 - Majority Label: 5
# Window ID: subject101_1575 - Majority Label: 5
# Window ID: subject101_1576 - Majority Label: 5
# Window ID: subject101_1577 - Majority Label: 5
# Window ID: subject101_1578 - Majority Label: 5
# Window ID: subject101_1579 - Majority Label: 5
# Window ID: subject101_158 - Majority Label: 1
# Window ID: subject101_1580 - Majority Label: 24
# Window ID: subject101_1581 - Majority Label: 24
# Window ID: subject101_1582 - Majority Label: 24
# Window ID: subject101_1583 - Majority Label: 24
# Window ID: subject101_1584 - Majority Label: 24
# Window ID: subject101_1585 - Majority Label: 24
# Window ID: subject101_1586 - Majority Label: 24
# Window ID: subject101_1587 - Majority Label: 24
# Window ID: subject101_1588 - Majority Label: 24
# Window ID: subject101_1589 - Majority Label: 24
# Window ID: subject101_159 - Majority Label: 1
# Window ID: subject101_1590 - Majority Label: 24
# Window ID: subject101_1591 - Majority Label: 24
# Window ID: subject101_1592 - Majority Label: 24
# Window ID: subject101_1593 - Majority Label: 24
# Window ID: subject101_1594 - Majority Label: 24
# Window ID: subject101_1595 - Majority Label: 24
# Window ID: subject101_1596 - Majority Label: 24
# Window ID: subject101_1597 - Majority Label: 24
# Window ID: subject101_1598 - Majority Label: 24
# Window ID: subject101_1599 - Majority Label: 24
# Window ID: subject101_16 - Majority Label: 1
# Window ID: subject101_160 - Majority Label: 1
# Window ID: subject101_1600 - Majority Label: 24
# Window ID: subject101_1601 - Majority Label: 24
# Window ID: subject101_1602 - Majority Label: 24
# Window ID: subject101_1603 - Majority Label: 24
# Window ID: subject101_1604 - Majority Label: 24
# Window ID: subject101_1605 - Majority Label: 24
# Window ID: subject101_1606 - Majority Label: 24
# Window ID: subject101_1607 - Majority Label: 24
# Window ID: subject101_1608 - Majority Label: 24
# Window ID: subject101_1609 - Majority Label: 24
# Window ID: subject101_161 - Majority Label: 1
# Window ID: subject101_1610 - Majority Label: 24
# Window ID: subject101_1611 - Majority Label: 24
# Window ID: subject101_1612 - Majority Label: 24
# Window ID: subject101_1613 - Majority Label: 24
# Window ID: subject101_1614 - Majority Label: 24
# Window ID: subject101_1615 - Majority Label: 24
# Window ID: subject101_1616 - Majority Label: 24
# Window ID: subject101_1617 - Majority Label: 24
# Window ID: subject101_1618 - Majority Label: 24
# Window ID: subject101_1619 - Majority Label: 24
# Window ID: subject101_162 - Majority Label: 1
# Window ID: subject101_1620 - Majority Label: 24
# Window ID: subject101_1621 - Majority Label: 24
# Window ID: subject101_1622 - Majority Label: 24
# Window ID: subject101_1623 - Majority Label: 24
# Window ID: subject101_1624 - Majority Label: 24
# Window ID: subject101_1625 - Majority Label: 24
# Window ID: subject101_1626 - Majority Label: 24
# Window ID: subject101_1627 - Majority Label: 24
# Window ID: subject101_1628 - Majority Label: 24
# Window ID: subject101_1629 - Majority Label: 24
# Window ID: subject101_163 - Majority Label: 1
# Window ID: subject101_1630 - Majority Label: 24
# Window ID: subject101_1631 - Majority Label: 24
# Window ID: subject101_1632 - Majority Label: 24
# Window ID: subject101_1633 - Majority Label: 24
# Window ID: subject101_1634 - Majority Label: 24
# Window ID: subject101_1635 - Majority Label: 24
# Window ID: subject101_1636 - Majority Label: 24
# Window ID: subject101_1637 - Majority Label: 24
# Window ID: subject101_1638 - Majority Label: 24
# Window ID: subject101_1639 - Majority Label: 24
# Window ID: subject101_164 - Majority Label: 1
# Window ID: subject101_1640 - Majority Label: 24
# Window ID: subject101_1641 - Majority Label: 24
# Window ID: subject101_1642 - Majority Label: 24
# Window ID: subject101_1643 - Majority Label: 24
# Window ID: subject101_1644 - Majority Label: 24
# Window ID: subject101_1645 - Majority Label: 24
# Window ID: subject101_1646 - Majority Label: 24
# Window ID: subject101_1647 - Majority Label: 24
# Window ID: subject101_1648 - Majority Label: 24
# Window ID: subject101_1649 - Majority Label: 24
# Window ID: subject101_165 - Majority Label: 1
# Window ID: subject101_1650 - Majority Label: 24
# Window ID: subject101_1651 - Majority Label: 24
# Window ID: subject101_1652 - Majority Label: 24
# Window ID: subject101_1653 - Majority Label: 24
# Window ID: subject101_1654 - Majority Label: 24
# Window ID: subject101_1655 - Majority Label: 24
# Window ID: subject101_1656 - Majority Label: 24
# Window ID: subject101_1657 - Majority Label: 24
# Window ID: subject101_1658 - Majority Label: 24
# Window ID: subject101_1659 - Majority Label: 24
# Window ID: subject101_166 - Majority Label: 1
# Window ID: subject101_1660 - Majority Label: 24
# Window ID: subject101_1661 - Majority Label: 24
# Window ID: subject101_1662 - Majority Label: 24
# Window ID: subject101_1663 - Majority Label: 24
# Window ID: subject101_1664 - Majority Label: 24
# Window ID: subject101_1665 - Majority Label: 24
# Window ID: subject101_167 - Majority Label: 1
# Window ID: subject101_168 - Majority Label: 1
# Window ID: subject101_169 - Majority Label: 1
# Window ID: subject101_17 - Majority Label: 1
# Window ID: subject101_170 - Majority Label: 1
# Window ID: subject101_171 - Majority Label: 1
# Window ID: subject101_172 - Majority Label: 1
# Window ID: subject101_173 - Majority Label: 1
# Window ID: subject101_174 - Majority Label: 1
# Window ID: subject101_175 - Majority Label: 1
# Window ID: subject101_176 - Majority Label: 1
# Window ID: subject101_177 - Majority Label: 1
# Window ID: subject101_178 - Majority Label: 1
# Window ID: subject101_179 - Majority Label: 1
# Window ID: subject101_18 - Majority Label: 1
# Window ID: subject101_180 - Majority Label: 1
# Window ID: subject101_181 - Majority Label: 2
# Window ID: subject101_182 - Majority Label: 2
# Window ID: subject101_183 - Majority Label: 2
# Window ID: subject101_184 - Majority Label: 2
# Window ID: subject101_185 - Majority Label: 2
# Window ID: subject101_186 - Majority Label: 2
# Window ID: subject101_187 - Majority Label: 2
# Window ID: subject101_188 - Majority Label: 2
# Window ID: subject101_189 - Majority Label: 2
# Window ID: subject101_19 - Majority Label: 1
# Window ID: subject101_190 - Majority Label: 2
# Window ID: subject101_191 - Majority Label: 2
# Window ID: subject101_192 - Majority Label: 2
# Window ID: subject101_193 - Majority Label: 2
# Window ID: subject101_194 - Majority Label: 2
# Window ID: subject101_195 - Majority Label: 2
# Window ID: subject101_196 - Majority Label: 2
# Window ID: subject101_197 - Majority Label: 2
# Window ID: subject101_198 - Majority Label: 2
# Window ID: subject101_199 - Majority Label: 2
# Window ID: subject101_2 - Majority Label: 1
# Window ID: subject101_20 - Majority Label: 1
# Window ID: subject101_200 - Majority Label: 2
# Window ID: subject101_201 - Majority Label: 2
# Window ID: subject101_202 - Majority Label: 2
# Window ID: subject101_203 - Majority Label: 2
# Window ID: subject101_204 - Majority Label: 2
# Window ID: subject101_205 - Majority Label: 2
# Window ID: subject101_206 - Majority Label: 2
# Window ID: subject101_207 - Majority Label: 2
# Window ID: subject101_208 - Majority Label: 2
# Window ID: subject101_209 - Majority Label: 2
# Window ID: subject101_21 - Majority Label: 1
# Window ID: subject101_210 - Majority Label: 2
# Window ID: subject101_211 - Majority Label: 2
# Window ID: subject101_212 - Majority Label: 2
# Window ID: subject101_213 - Majority Label: 2
# Window ID: subject101_214 - Majority Label: 2
# Window ID: subject101_215 - Majority Label: 2
# Window ID: subject101_216 - Majority Label: 2
# Window ID: subject101_217 - Majority Label: 2
# Window ID: subject101_218 - Majority Label: 2
# Window ID: subject101_219 - Majority Label: 2
# Window ID: subject101_22 - Majority Label: 1
# Window ID: subject101_220 - Majority Label: 2
# Window ID: subject101_221 - Majority Label: 2
# Window ID: subject101_222 - Majority Label: 2
# Window ID: subject101_223 - Majority Label: 2
# Window ID: subject101_224 - Majority Label: 2
# Window ID: subject101_225 - Majority Label: 2
# Window ID: subject101_226 - Majority Label: 2
# Window ID: subject101_227 - Majority Label: 2
# Window ID: subject101_228 - Majority Label: 2
# Window ID: subject101_229 - Majority Label: 2
# Window ID: subject101_23 - Majority Label: 1
# Window ID: subject101_230 - Majority Label: 2
# Window ID: subject101_231 - Majority Label: 2
# Window ID: subject101_232 - Majority Label: 2
# Window ID: subject101_233 - Majority Label: 2
# Window ID: subject101_234 - Majority Label: 2
# Window ID: subject101_235 - Majority Label: 2
# Window ID: subject101_236 - Majority Label: 2
# Window ID: subject101_237 - Majority Label: 2
# Window ID: subject101_238 - Majority Label: 2
# Window ID: subject101_239 - Majority Label: 2
# Window ID: subject101_24 - Majority Label: 1
# Window ID: subject101_240 - Majority Label: 2
# Window ID: subject101_305 - Majority Label: 2
# Window ID: subject101_306 - Majority Label: 2
# Window ID: subject101_307 - Majority Label: 2
# Window ID: subject101_308 - Majority Label: 2
# Window ID: subject101_309 - Majority Label: 2
# Window ID: subject101_31 - Majority Label: 1
# Window ID: subject101_310 - Majority Label: 2
# Window ID: subject101_311 - Majority Label: 2
# Window ID: subject101_312 - Majority Label: 2
# Window ID: subject101_313 - Majority Label: 2
# Window ID: subject101_314 - Majority Label: 2
# Window ID: subject101_315 - Majority Label: 2
# Window ID: subject101_316 - Majority Label: 2
# Window ID: subject101_317 - Majority Label: 2
# Window ID: subject101_318 - Majority Label: 2
# Window ID: subject101_319 - Majority Label: 2
# Window ID: subject101_32 - Majority Label: 1
# Window ID: subject101_320 - Majority Label: 2
# Window ID: subject101_321 - Majority Label: 2
# Window ID: subject101_322 - Majority Label: 2
# Window ID: subject101_323 - Majority Label: 2
# Window ID: subject101_324 - Majority Label: 2
# Window ID: subject101_325 - Majority Label: 2
# Window ID: subject101_326 - Majority Label: 2
# Window ID: subject101_327 - Majority Label: 2
# Window ID: subject101_328 - Majority Label: 2
# Window ID: subject101_329 - Majority Label: 2
# Window ID: subject101_33 - Majority Label: 1
# Window ID: subject101_330 - Majority Label: 2
# Window ID: subject101_331 - Majority Label: 2
# Window ID: subject101_332 - Majority Label: 2
# Window ID: subject101_333 - Majority Label: 2
# Window ID: subject101_334 - Majority Label: 2
# Window ID: subject101_335 - Majority Label: 2
# Window ID: subject101_336 - Majority Label: 2
# Window ID: subject101_337 - Majority Label: 2
# Window ID: subject101_338 - Majority Label: 3
# Window ID: subject101_339 - Majority Label: 3
# Window ID: subject101_34 - Majority Label: 1
# Window ID: subject101_340 - Majority Label: 3
# Window ID: subject101_341 - Majority Label: 3
# Window ID: subject101_342 - Majority Label: 3
# Window ID: subject101_343 - Majority Label: 3
# Window ID: subject101_344 - Majority Label: 3
# Window ID: subject101_345 - Majority Label: 3
# Window ID: subject101_346 - Majority Label: 3
# Window ID: subject101_347 - Majority Label: 3
# Window ID: subject101_348 - Majority Label: 3
# Window ID: subject101_349 - Majority Label: 3
# Window ID: subject101_35 - Majority Label: 1
# Window ID: subject101_350 - Majority Label: 3
# Window ID: subject101_351 - Majority Label: 3
# Window ID: subject101_352 - Majority Label: 3
# Window ID: subject101_353 - Majority Label: 3
# Window ID: subject101_354 - Majority Label: 3
# Window ID: subject101_355 - Majority Label: 3
# Window ID: subject101_356 - Majority Label: 3
# Window ID: subject101_357 - Majority Label: 3
# Window ID: subject101_358 - Majority Label: 3
# Window ID: subject101_359 - Majority Label: 3
# Window ID: subject101_36 - Majority Label: 1
# Window ID: subject101_360 - Majority Label: 3
# Window ID: subject101_361 - Majority Label: 3
# Window ID: subject101_362 - Majority Label: 3
# Window ID: subject101_363 - Majority Label: 3
# Window ID: subject101_364 - Majority Label: 3
# Window ID: subject101_365 - Majority Label: 3
# Window ID: subject101_366 - Majority Label: 3
# Window ID: subject101_367 - Majority Label: 3
# Window ID: subject101_368 - Majority Label: 3
# Window ID: subject101_369 - Majority Label: 3
# Window ID: subject101_37 - Majority Label: 1
# Window ID: subject101_370 - Majority Label: 3
# Window ID: subject101_371 - Majority Label: 3
# Window ID: subject101_372 - Majority Label: 3
# Window ID: subject101_373 - Majority Label: 3
# Window ID: subject101_374 - Majority Label: 3
# Window ID: subject101_375 - Majority Label: 3
# Window ID: subject101_376 - Majority Label: 3
# Window ID: subject101_377 - Majority Label: 3
# Window ID: subject101_378 - Majority Label: 3
# Window ID: subject101_379 - Majority Label: 3
# Window ID: subject101_38 - Majority Label: 1
# Window ID: subject101_380 - Majority Label: 3
# Window ID: subject101_381 - Majority Label: 3
# Window ID: subject101_382 - Majority Label: 3
# Window ID: subject101_383 - Majority Label: 3
# Window ID: subject101_384 - Majority Label: 3
# Window ID: subject101_385 - Majority Label: 3
# Window ID: subject101_386 - Majority Label: 3
# Window ID: subject101_387 - Majority Label: 3
# Window ID: subject101_388 - Majority Label: 3
# Window ID: subject101_389 - Majority Label: 3
# Window ID: subject101_39 - Majority Label: 1
# Window ID: subject101_390 - Majority Label: 3
# Window ID: subject101_391 - Majority Label: 3
# Window ID: subject101_392 - Majority Label: 3
# Window ID: subject101_393 - Majority Label: 3
# Window ID: subject101_394 - Majority Label: 3
# Window ID: subject101_395 - Majority Label: 3
# Window ID: subject101_396 - Majority Label: 3
# Window ID: subject101_397 - Majority Label: 3
# Window ID: subject101_398 - Majority Label: 3
# Window ID: subject101_399 - Majority Label: 3
# Window ID: subject101_4 - Majority Label: 1
# Window ID: subject101_40 - Majority Label: 1
# Window ID: subject101_400 - Majority Label: 3
# Window ID: subject101_401 - Majority Label: 3
# Window ID: subject101_402 - Majority Label: 3
# Window ID: subject101_403 - Majority Label: 3
# Window ID: subject101_404 - Majority Label: 3
# Window ID: subject101_405 - Majority Label: 3
# Window ID: subject101_406 - Majority Label: 3
# Window ID: subject101_407 - Majority Label: 3
# Window ID: subject101_408 - Majority Label: 3
# Window ID: subject101_409 - Majority Label: 3
# Window ID: subject101_41 - Majority Label: 1
# Window ID: subject101_410 - Majority Label: 3
# Window ID: subject101_411 - Majority Label: 3
# Window ID: subject101_412 - Majority Label: 3
# Window ID: subject101_413 - Majority Label: 3
# Window ID: subject101_414 - Majority Label: 3
# Window ID: subject101_415 - Majority Label: 3
# Window ID: subject101_416 - Majority Label: 3
# Window ID: subject101_417 - Majority Label: 3
# Window ID: subject101_418 - Majority Label: 3
# Window ID: subject101_419 - Majority Label: 3
# Window ID: subject101_42 - Majority Label: 1
# Window ID: subject101_420 - Majority Label: 3
# Window ID: subject101_421 - Majority Label: 3
# ...
# Window ID: subject108_729 - Majority Label: 16
# Window ID: subject108_73 - Majority Label: 1
# Window ID: subject108_730 - Majority Label: 16
# Window ID: subject108_731 - Majority Label: 16
# Window ID: subject108_732 - Majority Label: 16
# Window ID: subject108_733 - Majority Label: 16
# Window ID: subject108_734 - Majority Label: 16
# Window ID: subject108_735 - Majority Label: 16
# Window ID: subject108_736 - Majority Label: 16
# Window ID: subject108_737 - Majority Label: 16
# Window ID: subject108_738 - Majority Label: 16
# Window ID: subject108_993 - Majority Label: 13
# Window ID: subject108_994 - Majority Label: 13
# Window ID: subject108_995 - Majority Label: 13
# Window ID: subject108_996 - Majority Label: 13
# Window ID: subject108_997 - Majority Label: 13
# Window ID: subject108_998 - Majority Label: 13
# Window ID: subject108_999 - Majority Label: 13
# Window ID: subject109_0 - Majority Label: 24
# Window ID: subject109_1 - Majority Label: 24
# Window ID: subject109_10 - Majority Label: 24
# Window ID: subject109_11 - Majority Label: 24
# Window ID: subject109_12 - Majority Label: 24
# Window ID: subject109_13 - Majority Label: 24
# Window ID: subject109_14 - Majority Label: 24
# Window ID: subject109_15 - Majority Label: 24
# Window ID: subject109_16 - Majority Label: 24
# Window ID: subject109_17 - Majority Label: 24
# Window ID: subject109_18 - Majority Label: 24
# Window ID: subject109_19 - Majority Label: 24
# Window ID: subject109_2 - Majority Label: 24
# Window ID: subject109_20 - Majority Label: 24
# Window ID: subject109_21 - Majority Label: 24
# Window ID: subject109_22 - Majority Label: 24
# Window ID: subject109_23 - Majority Label: 24
# Window ID: subject109_24 - Majority Label: 24
# Window ID: subject109_25 - Majority Label: 24
# Window ID: subject109_26 - Majority Label: 24
# Window ID: subject109_27 - Majority Label: 24
# Window ID: subject109_28 - Majority Label: 24
# Window ID: subject109_29 - Majority Label: 24
# Window ID: subject109_3 - Majority Label: 24
# Window ID: subject109_30 - Majority Label: 24
# Window ID: subject109_31 - Majority Label: 24
# Window ID: subject109_32 - Majority Label: 24
# Window ID: subject109_33 - Majority Label: 24
# Window ID: subject109_34 - Majority Label: 24
# Window ID: subject109_35 - Majority Label: 24
# Window ID: subject109_36 - Majority Label: 24
# Window ID: subject109_37 - Majority Label: 24
# Window ID: subject109_38 - Majority Label: 24
# Window ID: subject109_39 - Majority Label: 24
# Window ID: subject109_4 - Majority Label: 24
# Window ID: subject109_40 - Majority Label: 24
# Window ID: subject109_41 - Majority Label: 24
# Window ID: subject109_5 - Majority Label: 24
# Window ID: subject109_6 - Majority Label: 24
# Window ID: subject109_7 - Majority Label: 24
# Window ID: subject109_8 - Majority Label: 24
# Window ID: subject109_9 - Majority Label: 24

# %%
windows_per_subject = pamap_windowed.groupby('subject_id').size()/150
print(f'Promedio de ventanas por cada sujeto: {windows_per_subject.mean()}')

windows_per_activity = pamap_windowed.groupby('activityID').size()/150
print(f'Promedio de ventanas por cada actividad: {windows_per_activity.mean()}')
# Out:
# Promedio de ventanas por cada sujeto: 1438.6666666666667
# Promedio de ventanas por cada actividad: 1079.0

# %% [markdown]
# ## 2.2 Extracción de características

# %% [markdown]
# Ahora bien, en el estudio de Lara (2011), dieron a relucir que la información provista por datos de signos vitales no es necesaria si las actividades a reconocer son caminando o bajando, pero, para actividades como corriendo, estar sentado o asendiendo pueden ser de utilidad. Sin embargo, en el artículo de Rehman (2024), hacen uso solamente de los sensores del acelerómetro giroscopio y magnetométro, debido a que otro estudió de igual forma lo trabajó así. Por ello nosotros tomamos el mismo enfoque.

# %%
class InertialSensor:
    def __init__(self, x, y, z):
        """
        Inicializa el acelerómetro con sus 3 señales.
        
        Parámetros:
          x: array-like, señal del eje x.
          y: array-like, señal del eje y.
          z: array-like, señal del eje z.
        """
        self.x = np.array(x)
        self.y = np.array(y)
        self.z = np.array(z)
        
    def compute_magnitude(self):
        return np.sqrt(self.x**2 + self.y**2 + self.z**2)
    
    def extract_features(self):
        # 1. Medias de cada eje
        mean_x = np.mean(self.x)
        mean_y = np.mean(self.y)
        mean_z = np.mean(self.z)
        
        # 2. Desviaciones estándar
        std_x = np.std(self.x)
        std_y = np.std(self.y)
        std_z = np.std(self.z)
        
        # 3. Valores máximos
        max_x = np.max(self.x)
        max_y = np.max(self.y)
        max_z = np.max(self.z)
        
        # 4. Correlaciones entre cada par de ejes
        corr_xy = np.corrcoef(self.x, self.y)[0, 1]
        corr_xz = np.corrcoef(self.x, self.z)[0, 1]
        corr_yz = np.corrcoef(self.y, self.z)[0, 1]
        
        # 5,6,7,8. Features derivadas de la magnitud
        magnitude = self.compute_magnitude()
        mean_magnitude = np.mean(magnitude)
        std_magnitude = np.std(magnitude)
        auc = np.sum(magnitude)
        mean_diff = np.mean(np.diff(magnitude)) if len(magnitude) > 1 else 0.0
        
        # Vector de features
        feature_vector = np.array([
            mean_x, mean_y, mean_z,
            std_x, std_y, std_z,
            max_x, max_y, max_z,
            corr_xy, corr_xz, corr_yz,
            mean_magnitude, std_magnitude, auc, mean_diff
        ])
        
        return feature_vector

# %%
import numpy as np
df_to_extract_features = pamap_windowed
numeric_features_list = []
labels = []

for seg, group in df_to_extract_features.groupby("window_id"):
    #Features obtenidos de los sensores en la mano
    H_acc_features = InertialSensor(
        group.IMU_Hand_acceleration_16g_x,
        group.IMU_Hand_acceleration_16g_y,
        group.IMU_Hand_acceleration_16g_z
    ).extract_features()
    H_gyro_features = InertialSensor(
        group.IMU_Hand_gyroscope_x,
        group.IMU_Hand_gyroscope_y,
        group.IMU_Hand_gyroscope_z,
    ).extract_features()
    H_mag_features = InertialSensor(
        group.IMU_Hand_magnetometer_x,
        group.IMU_Hand_magnetometer_y,
        group.IMU_Hand_magnetometer_z,
    ).extract_features()
        #Features obtenidos de los sensores en el pecho
    C_acc_features = InertialSensor(
        group.IMU_Chest_acceleration_16g_x,
        group.IMU_Chest_acceleration_16g_y,
        group.IMU_Chest_acceleration_16g_z
    ).extract_features()
    C_gyro_features = InertialSensor(
        group.IMU_Chest_gyroscope_x,
        group.IMU_Chest_gyroscope_y,
        group.IMU_Chest_gyroscope_z,
    ).extract_features()
    C_mag_features = InertialSensor(
        group.IMU_Chest_magnetometer_x,
        group.IMU_Chest_magnetometer_y,
        group.IMU_Chest_magnetometer_z,
    ).extract_features()
    #Features obtenidos de los sensores en el tobillo
    A_acc_features = InertialSensor(
        group.IMU_Ankle_acceleration_16g_x,
        group.IMU_Ankle_acceleration_16g_y,
        group.IMU_Ankle_acceleration_16g_z
    ).extract_features()
    A_gyro_features = InertialSensor(
        group.IMU_Ankle_gyroscope_x,
        group.IMU_Ankle_gyroscope_y,
        group.IMU_Ankle_gyroscope_z,
    ).extract_features()
    A_mag_features = InertialSensor(
        group.IMU_Ankle_magnetometer_x,
        group.IMU_Ankle_magnetometer_y,
        group.IMU_Ankle_magnetometer_z,
    ).extract_features()
    
    feature_vector = np.concatenate([
        H_acc_features, H_gyro_features, H_mag_features,
        C_acc_features, C_gyro_features, C_mag_features,
        A_acc_features, A_gyro_features, A_mag_features
    ]).astype(float)
    
    numeric_features_list.append(feature_vector)
    labels.append(group["labels_in_window"].iloc[0])

sensor_locations = ["hand"]
sensor_types = ["acc", "gyro", "mag"]
feature_names = [
    "mean_x", "mean_y", "mean_z", "std_x", "std_y", "std_z",
    "max_x", "max_y", "max_z", "corr_xy", "corr_xz", "corr_yz",
    "mean_mag", "std_mag", "auc", "mean_diff"
]

feature_columns = [
    f"{loc}_{typ}_{feat}"
    for loc in sensor_locations
    for typ in sensor_types
    for feat in feature_names
]
        
sensor_locations = ["chest"]
sensor_types = ["acc", "gyro", "mag"]
feature_columns.extend([
    f"{loc}_{typ}_{feat}"
    for loc in sensor_locations
    for typ in sensor_types
    for feat in feature_names
])

sensor_locations = ["ankle"]
sensor_types = ["acc", "gyro", "mgnt"]
feature_columns.extend([
    f"{loc}_{typ}_{feat}"
    for loc in sensor_locations
    for typ in sensor_types
    for feat in feature_names
])

# Create DataFrame for numeric features and convert to float
df_numeric = pd.DataFrame(np.array(numeric_features_list), columns=feature_columns)

# Create DataFrame for labels
df_labels = pd.DataFrame(labels, columns=["activity"])

# Concatenate numeric features and labels
pamap_features = pd.concat([df_numeric, df_labels], axis=1)

# Optionally, check the data types to confirm
pamap_features.shape
pamap_features
# Out:
#        hand_acc_mean_x  hand_acc_mean_y  hand_acc_mean_z  hand_acc_std_x  \
# 0             1.476462         7.183104         6.263181        1.493137
# 1            -1.580164         9.098362         3.046503        0.698351
# 2             0.318060         5.719075         7.957812        0.087042
# 3             3.793341        -3.944923        -8.212290        0.060836
# 4            -2.701973         6.519174         6.585910        1.101292
# ...                ...              ...              ...             ...
# 12943         0.538799        11.090765        -1.331692        4.820491
# 12944         0.161949         7.176982        -2.381768        5.696166
# 12945        -2.865762        11.344199         1.629505        2.861371
# 12946        -2.440181         7.321234        -0.454268        5.156909
# 12947        -1.177949         9.930621        -0.537304        5.900077
#
#        hand_acc_std_y  hand_acc_std_z  hand_acc_max_x  hand_acc_max_y  \
# 0            0.891178        0.773317        3.184930         9.38736
# 1            1.264988        1.029115        1.103640        12.01160
# 2            0.177270        0.135302        0.613322         6.04065
# 3            0.072421        0.094537        3.958310        -3.77111
# 4            1.324894        0.875959        0.135733        10.32980
# ...               ...             ...             ...             ...
# 12943       12.603037        5.292219       12.310300        34.85990
# 12944       15.915406        7.964756       13.190700        36.25800
# 12945        5.903191        3.707454        8.405530        28.46640
# 12946       10.600009        7.625614        9.904520        28.85750
# 12947       14.273260        6.699514       12.967500        37.96040
#
#        hand_acc_max_z  hand_acc_corr_xy  ...  ankle_mgnt_max_y  \
# 0             8.69773         -0.062893  ...         -35.18610
# 1             5.14512         -0.448855  ...         -35.23700
# 2             8.26579         -0.198240  ...          44.94040
# 3            -7.97182          0.242557  ...          21.67320
# 4             9.59792         -0.256611  ...         -34.46280
# ...               ...               ...  ...               ...
# 12943        10.50140         -0.208746  ...         -17.27500
# 12944        30.55700          0.087518  ...               NaN
# 12945        18.23930         -0.093056  ...          23.81200
# 12946        12.95720         -0.129110  ...         -10.25700
# 12947        21.73800          0.113102  ...          -8.03201
#
#        ankle_mgnt_max_z  ankle_mgnt_corr_xy  ankle_mgnt_corr_xz  \
# 0             -57.11420           -0.429460           -0.151932
# 1             -57.83440           -0.925066            0.112084
# 2              -8.61565           -0.190123            0.078203
# 3              40.93500           -0.087881           -0.082397
# 4               3.79722           -0.736550            0.023367
# ...                 ...                 ...                 ...
# 12943          23.45170           -0.956532            0.873342
# 12944               NaN                 NaN                 NaN
# 12945          16.76660           -0.267715            0.438702
# 12946          15.78230           -0.981514            0.140041
# 12947          20.04010           -0.960875            0.374627
#
#        ankle_mgnt_corr_yz  ankle_mgnt_mean_mag  ankle_mgnt_std_mag  \
# 0                0.104818            92.160149            0.398534
# 1               -0.289666            92.330535            0.427368
# 2               -0.055490            47.353755            0.479386
# 3                0.076284            49.727292            0.432894
# 4               -0.025351            62.663169            0.406113
# ...                   ...                  ...                 ...
# 12943           -0.758037            46.338818            0.594737
# 12944                 NaN                  NaN                 NaN
# 12945           -0.880136            46.609012            0.742160
# 12946           -0.052437            46.481226            0.730255
# 12947           -0.175187            46.974582            0.689992
#
#        ankle_mgnt_auc  ankle_mgnt_mean_diff  activity
# 0        13824.022413              0.002502         1
# 1        13849.580232             -0.001155         1
# 2         7103.063286              0.004484         1
# 3         7459.093851             -0.004624         1
# 4         9399.475384             -0.003671         4
# ...               ...                   ...       ...
# 12943     6950.822626             -0.004561        24
# 12944             NaN                   NaN        24
# 12945     6991.351828              0.006192        24
# 12946     6972.183902             -0.000203        24
# 12947     7046.187299              0.005410        24
#
# [12948 rows x 145 columns]

# %%
pamap_features.shape
# Out:
# (12948, 145)

# %% [markdown]
# Ahora con estas features podemos hacer las siguientes fases

# %% [markdown]
# ## 2.3 Train Test Splitting, Class imabalnce & Normalization

# %% [markdown]
# A continuación, se presenta la pipeline que representa los pasos para el entrenamiento de los modelos. Para un correcto entrenamiento se deben tomar los siguientes pasos:
# 1. Oversampling: debido al gran desbalance de clases, se opta por técnicas de sobremuestreo que han sido utilizadas en la literatura, entre las que han demostrado mayor efectividad se encuentra SMOTE.
# 2. Escalado: Debido a que en el EDA se puede apreciar que algunas features están en diferentes escalas, hay que aplicar alguna técnica de escalado que evite que las features con mayor escala representen mayor importancia, es por eso que se opta por un MinMaxScaler que igualmente ha demostrado buenos resultados en la literatura.
# 3. Entrenamiento con el modelo

# %%
from sklearn.model_selection import cross_val_score
from imblearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE  


X = pamap_features.drop(columns=['activity']).values  
y = pamap_features['activity'].values 
 
scaler = MinMaxScaler()

def execute_pipeline(model, X, y):
    pipeline = make_pipeline(
        SMOTE(sampling_strategy='all', random_state=42), 
        scaler,  
        model
    )
    pipeline.fit(X, y)
    scorespipe = cross_val_score(pipeline, X, y, cv=10, scoring="f1_macro")
    return scorespipe
